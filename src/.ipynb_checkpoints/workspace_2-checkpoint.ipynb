# %%
using IJulia
#installkernel("Julia (n threads)", env=Dict("JULIA_NUM_THREADS"=>"n"))

# %%
include("ValueFunctions.jl")
include("BeliefStateTransitions.jl")
include("../examples/SurplusProduction.jl")
# Out:
# Main.SurplusProduction

# %%
# harvest = vcat(collect(0.0:1.0:9.0),collect(10:2.5:50))
# observations = [0,1]
# actions = reshape(collect(Iterators.product(harvest, observations)), length(harvest)*length(observations))


# V = ValueFunctions.init_Norm2DGrid(log(200.0),log(0.5),0.25,100)
# model=BeliefStateTransitions.init_model(SurplusProduction.T,
#     SurplusProduction.H,
#     actions,
#     SurplusProduction.Sigma_O,
#     SurplusProduction.Sigma_N,
#     1)

# grid1=BeliefStateTransitions.init_transitions("particle Quad",model,V;Nfilter=20000)

# BeliefStateTransitions.computeTransitions!(grid1)
# using JLD2
# @save "grid_2.jld2" grid1

# %%
"quadrature"

harvest = collect(0.0:0.5:50)
observations = [0,1]
actions = reshape(collect(Iterators.product(harvest, observations)), length(harvest)*length(observations))


V = ValueFunctions.init_Norm2DGrid(log(150.0),log(0.5),0.4,150)
model=BeliefStateTransitions.init_model(SurplusProduction.T,
    SurplusProduction.H,
    actions,
    SurplusProduction.Sigma_O2,
    SurplusProduction.Sigma_N,
    1)

grid4=BeliefStateTransitions.init_transitions("quadrature",model,V;mQuad = 35)

BeliefStateTransitions.computeTransitions!(grid4)

using JLD2
@save "grid_3.jld4" grid4
# Out:
# ┌ Info:  started timer at: 2022-09-26T10:28:06.517
# └ @ TickTock /Users/johnbuckner/.julia/packages/TickTock/fGILW/src/TickTock.jl:54
# progress = 2.0%  time: 113.0
# progress = 4.0%  time: 221.0
# progress = 6.0%  time: 329.0
# progress = 8.0%  time: 436.0
# progress = 10.0%  time: 542.0
# progress = 12.0%  time: 653.0
# progress = 14.0%  time: 766.0
# progress = 16.0%  time: 878.0
# progress = 18.0%  time: 982.0
# progress = 20.0%  time: 1086.0
# progress = 22.0%  time: 1194.0
# progress = 24.0%  time: 1301.0
# progress = 26.0%  time: 1408.0
# progress = 28.0%  time: 1515.0
# progress = 30.0%  time: 1616.0
# progress = 32.0%  time: 1722.0
# progress = 34.0%  time: 1830.0
# progress = 36.0%  time: 1938.0
# progress = 38.0%  time: 2045.0
# progress = 40.0%  time: 2154.0
# progress = 42.0%  time: 2261.0
# progress = 44.0%  time: 2369.0
# progress = 46.0%  time: 2476.0
# progress = 48.0%  time: 2583.0
# progress = 50.0%  time: 2691.0
# progress = 52.0%  time: 2798.0
# ...

# %%
using Plots
N = 150
acc = zeros(N,N)
for i in 1:N
    for j in 1:N
        acc[i,j]=sum(grid4.values[i,j,103,:,1] .* grid4.weights)
    end 
end 
Plots.heatmap(grid4.nodesVar,exp.(grid4.nodesMean),exp.(acc))

# %%
acc = zeros(N,N)
for i in 1:N
    for j in 1:N
        acc[i,j]=sum(grid4.values[i,j,102,:,2] .* grid4.weights)
    end 
end 
Plots.heatmap(grid4.nodesVar,exp.(grid4.nodesMean),acc)

# %%
include("../examples/SurplusProduction.jl")

include("MDPsolver.jl")
cov = zeros(1,1)
cov[1,1] = 0.05

xQuad = MDPsolver.MvGaussHermite.init_mutable(10,zeros(1),cov)

struct objective2
    delta::Float64
    R::Function 
    actions::AbstractVector
end 
obj = objective2(0.925,(x,a) -> SurplusProduction.R(x,a[1],a[2]),[(0.0,0),(1.0,0),(10.0,1)])
V6 = MDPsolver.ValueFunctions.init_Norm2DGrid(log(150.0),log(0.5),0.4,150)
print(" ")
# Out:
# WARNING: replacing module SurplusProduction.
# WARNING: replacing module MDPsolver.

# %%
MDPsolver.solve_parallel(grid4,V6,obj,xQuad)
@save "sol_6.jld2" V6
# Out:
# interation: 1  convergence: 225000
# interation: 2  convergence: 1.3989013249816285e7
# interation: 3  convergence: 4.0610265057266215e6
# interation: 4  convergence: 1.896322544536972e6
# interation: 5  convergence: 4.145834354934717e7
# interation: 6  convergence: 2.125344234099636e9
# interation: 7  convergence: 8.580657518017867e10
# interation: 8  convergence: 2.36362264578275e13
# interation: 9  convergence: 3.8437773818416365e15
# interation: 10  convergence: 7.203322410569756e16
# interation: 11  convergence: 1.9278687788405384e18
# interation: 12  convergence: 7.495194117192846e20
# interation: 13  convergence: 4.032866576204198e23
# interation: 14  convergence: 3.128714288225124e26
# interation: 15  convergence: 1.525251487321158e30
# interation: 16  convergence: 7.289433459842285e32
# interation: 17  convergence: 2.93145985037411e35
# interation: 18  convergence: 1.0612883920119501e38
# interation: 19  convergence: 1.0678296906414543e40
# ...

# %%
using LaTeXStrings
meanNodes = log(0.5):0.005:log(125)
Plots.plot(exp.(meanNodes.+0.5*0.05),broadcast(x->V6([x,0.05]), meanNodes), label = L"\sigma^2 = 0.05")
Plots.plot!(exp.(meanNodes.+0.5*0.1),broadcast(x->V6([x,0.1]), meanNodes), label = L"\sigma^2 = 0.1")
Plots.plot!(exp.(meanNodes.+0.5*0.15),broadcast(x->V6([x,0.15]), meanNodes), label = L"\sigma^2 = 0.15")
Plots.plot!(exp.(meanNodes.+0.5*0.2),broadcast(x->V6([x,0.2]), meanNodes), label = L"\sigma^2 = 0.2")
Plots.plot!(exp.(meanNodes.+0.5*0.25),broadcast(x->V6([x,0.25]), meanNodes), label = L"\sigma^2 = 0.25",
            xlab = L"\hat{B}_t", ylab = L"NPV", legend = :bottomright)

# %%
include("../examples/SurplusProduction.jl")
obj = objective2(0.925,(x,a) -> SurplusProduction.R(x,a[1],a[2]),[(0.0,0),(1.0,0),(10.0,1)])
N = 100
harvest = zeros(N,N)
monitoring = zeros(N,N)
for i in 1:N
    for j in 1:N
        harvest[i,j],monitoring[i,j]=MDPsolver.policy!(zeros(2),i,j,grid3,V6,obj,xQuad)
    end 
end 
Plots.heatmap(grid3.nodesVar,exp.(grid3.nodesMean),harvest)
# Out:
# WARNING: replacing module SurplusProduction.
# UndefVarError: grid3 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ ./In[8]:8
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
using LaTeXStrings
Plots.plot(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[1]),
                broadcast(x->MDPsolver.policy!(zeros(2),x,1,grid3,V6,obj,xQuad)[1], 1:100),
               label = L"\sigma^2 = 0.001")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[25]),
            broadcast(x->MDPsolver.policy!(zeros(2),x,25,grid3,V6,obj,xQuad)[1], 1:100), 
            label = L"\sigma^2 = 0.06")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[50]),
            broadcast(x->MDPsolver.policy!(zeros(2),x,50,grid3,V6,obj,xQuad)[1], 1:100), 
            label = L"\sigma^2 = 0.12")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[75]),
            broadcast(x->MDPsolver.policy!(zeros(2),x,75,grid3,V6,obj,xQuad)[1], 1:100), 
            label = L"\sigma^2 = 0.18")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[100]),
                broadcast(x->MDPsolver.policy!(zeros(2),x,100,grid3,V6,obj,xQuad)[1], 1:100),
                label = L"\sigma^2 = 0.25", 
                xlab = L"\hat{B}_t", ylab = L"\hat{H}_t",
                legend =:bottomright)
# Out:
# UndefVarError: grid3 not defined
#
# Stacktrace:
#   [1] (::var"#15#16")(x::Int64)
#     @ Main ./In[9]:3
#   [2] _broadcast_getindex_evalf
#     @ ./broadcast.jl:670 [inlined]
#   [3] _broadcast_getindex
#     @ ./broadcast.jl:643 [inlined]
#   [4] getindex
#     @ ./broadcast.jl:597 [inlined]
#   [5] copy
#     @ ./broadcast.jl:899 [inlined]
#   [6] materialize
#     @ ./broadcast.jl:860 [inlined]
#   [7] broadcast(f::var"#15#16", As::UnitRange{Int64})
#     @ Base.Broadcast ./broadcast.jl:798
#   [8] top-level scope
#     @ In[9]:2
#   [9] eval
#     @ ./boot.jl:373 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %%
Plots.plot(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[1]),
                exp.(grid3.nodesMean.+0.5*grid3.nodesVar[1]) .- broadcast(x->MDPsolver.policy!(zeros(2),x,1,grid3,V6,obj,xQuad)[1], 1:100),
               label = L"\sigma^2 = 0.001")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[25]),
            exp.(grid3.nodesMean.+0.5*grid3.nodesVar[25]) .- broadcast(x->MDPsolver.policy!(zeros(2),x,25,grid3,V6,obj,xQuad)[1], 1:100), 
            label = L"\sigma^2 = 0.06")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[50]),
            exp.(grid3.nodesMean.+0.5*grid3.nodesVar[50]) .- broadcast(x->MDPsolver.policy!(zeros(2),x,50,grid3,V6,obj,xQuad)[1], 1:100), 
            label = L"\sigma^2 = 0.12")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[75]),
            exp.(grid3.nodesMean.+0.5*grid3.nodesVar[75]) .- broadcast(x->MDPsolver.policy!(zeros(2),x,75,grid3,V6,obj,xQuad)[1], 1:100), 
            label = L"\sigma^2 = 0.18")
Plots.plot!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[100]),
            exp.(grid3.nodesMean.+0.5*grid3.nodesVar[100]) .- broadcast(x->MDPsolver.policy!(zeros(2),x,100,grid3,V6,obj,xQuad)[1], 1:100),
                label = L"\sigma^2 = 0.25", 
                xlab = L"\hat{B}_t", ylab = L"\hat{H}_t",
                legend =:bottomright)
Plots.plot!([0,125],[0,125], color = "black", linestyle = :dash)
# Out:
# UndefVarError: grid3 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:1
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
Plots.heatmap(grid3.nodesVar,exp.(grid3.nodesMean),
                monitoring,
                xlab = L"\sigma^2_t", 
                ylab = L"\hat{B}_t")
# Out:
# UndefVarError: grid3 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[11]:1
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
Plots.scatter(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[1]),
                broadcast(x->MDPsolver.policy!(zeros(2),x,1,grid3,V6,obj,xQuad)[2] , 1:100),
               label = L"\sigma^2 = 0.001")
Plots.scatter!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[25]),
            broadcast(x->MDPsolver.policy!(zeros(2),x,25,grid3,V6,obj,xQuad)[2]+0.01, 1:100), 
            label = L"\sigma^2 = 0.06")
Plots.scatter!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[50]),
            broadcast(x->MDPsolver.policy!(zeros(2),x,50,grid3,V6,obj,xQuad)[2]+0.02, 1:100), 
            label = L"\sigma^2 = 0.12")
Plots.scatter!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[75]),
            broadcast(x->MDPsolver.policy!(zeros(2),x,75,grid3,V6,obj,xQuad)[2]+0.03, 1:100), 
            label = L"\sigma^2 = 0.18")
Plots.scatter!(exp.(grid3.nodesMean.+0.5*grid3.nodesVar[100]),
                broadcast(x->MDPsolver.policy!(zeros(2),x,100,grid3,V6,obj,xQuad)[2]+0.04, 1:100),
                label = L"\sigma^2 = 0.25", 
                xlab = L"\hat{B}_t", ylab = L"\hat{H}_t",
                legend =:right)
# Out:
# UndefVarError: grid3 not defined
#
# Stacktrace:
#   [1] (::var"#19#20")(x::Int64)
#     @ Main ./In[12]:2
#   [2] _broadcast_getindex_evalf
#     @ ./broadcast.jl:670 [inlined]
#   [3] _broadcast_getindex
#     @ ./broadcast.jl:643 [inlined]
#   [4] getindex
#     @ ./broadcast.jl:597 [inlined]
#   [5] copy
#     @ ./broadcast.jl:899 [inlined]
#   [6] materialize
#     @ ./broadcast.jl:860 [inlined]
#   [7] broadcast(f::var"#19#20", As::UnitRange{Int64})
#     @ Base.Broadcast ./broadcast.jl:798
#   [8] top-level scope
#     @ In[12]:1
#   [9] eval
#     @ ./boot.jl:373 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %%
include("MDPsolver.jl")
P=MDPsolver.ValueFunctions.init_Norm2DGrid_policy(log(125.0),log(0.5),0.25,100)
print(" ")
# Out:
# WARNING: replacing module MDPsolver.

# %%
@load "sol_3.jld2"
obj = objective2(0.925,(x,a) -> SurplusProduction.R(x,a[1],a[2]),[(0.0,0),(1.0,0),(10.0,1)])
MDPsolver.policy_parallel!(P,grid3,V3,obj,xQuad;threashold = 10^-2)
# Out:
# UndefVarError: grid3 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[14]:3
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
obj = objective2(0.925,(x,a) -> SurplusProduction.R3(x,a[1],a[2]),[(0.0,0),(1.0,0),(10.0,1)])
N = 100
B = exp(P.lower_mu):0.5:exp(P.upper_mu)
S =0:0.005:P.upper_sigma
harvest = zeros(length(B),length(S))
monitoring = zeros(length(B),length(S))

for i in 1:length(B)
    for j in 1:length(S)
        mu = log(B[i]) -0.5*S[j]
        harvest[i,j],monitoring[i,j]=P([mu, S[j]])
    end 
end 
p1=Plots.heatmap(S,B,harvest)
p2=Plots.heatmap(S,B,monitoring)
plot(p1,p2,layout=(1,2))

# %%
include("BeliefStateTransitions.jl")
include("MDPsolver.jl")
harvest = collect(0.0:0.5:50)
observations = [0,1]
actions = reshape(collect(Iterators.product(harvest, observations)), length(harvest)*length(observations))

model=BeliefStateTransitions.init_model(SurplusProduction.T,
    SurplusProduction.H,
    actions,
    SurplusProduction.Sigma_O,
    SurplusProduction.Sigma_N,
    1)

s0 = ([log(100)], [0.25;;])
x0 = ([log(100), 0])
T = 100
dat=MDPsolver.simulation(x0,s0,T,P,model)
print(" ")
# Out:
# WARNING: replacing module BeliefStateTransitions.
# WARNING: replacing module MDPsolver.

# %%
p1=Plots.plot(broadcast(i -> exp.(dat[2][i][1][1]), 1:T), color = "black", label = "estimate")
Plots.plot!(broadcast(i -> exp.(dat[2][i][1][1] + 2*sqrt(dat[2][i][2][1])), 1:T), 
            fillrange = broadcast(i -> exp.(dat[2][i][1][1] - 2*sqrt(dat[2][i][2][1])), 1:T), 
            alpha =0.2, color = "grey", label = "uncertainty", ylab = "Biomass")
Plots.scatter!(broadcast(i -> exp(dat[1][i][1]), 1:T), markersize= 2, label = L"B_t")
Plots.plot!(broadcast(i -> exp.(dat[2][i][1][1]- 2*sqrt(dat[2][i][2][1])), 1:T), color = "grey", alpha = 0.2, label = "")

p2=Plots.plot(broadcast(i -> dat[2][i][2][1], 1:T), color = "black", ylab = L"\sigma^2", label = "",xlab = "Time")
plot(p1,p2,layout=(2,1))

# %%
p1=Plots.plot(broadcast(i -> dat[3][i][1], 1:T), ylab = "Harvet", legend = false, color = "black")
p2=Plots.scatter(broadcast(i -> dat[3][i][2], 1:T), ylab = "observation", xlab = "Time",
                legend = false, color = "grey", markersize= 2.5)
plot(p1,p2,layout=(2,1))
